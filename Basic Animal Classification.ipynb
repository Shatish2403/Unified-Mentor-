# %%
import tensorflow as tf
from tensorflow.keras.models import Sequential
from tensorflow.keras.layers import Conv2D, MaxPooling2D, Flatten, Dense, Dropout
from tensorflow.keras.preprocessing.image import ImageDataGenerator

# Set the path for your dataset
dataset_dir = 'dataset'

# Define image dimensions and batch size
img_height, img_width = 224, 224
batch_size = 32

# Data Augmentation and Image Preprocessing with validation split
datagen = ImageDataGenerator(
    rescale=1./255,
    validation_split=0.2  # Split 20% of data for validation
)

# Load and preprocess the training data
train_generator = datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='training',  # Set as training data
    shuffle=True
)

# Load and preprocess the validation data
validation_generator = datagen.flow_from_directory(
    dataset_dir,
    target_size=(img_height, img_width),
    batch_size=batch_size,
    class_mode='categorical',
    subset='validation',  # Set as validation data
    shuffle=True
)

# Build the CNN model
model = Sequential([
    Conv2D(32, (3, 3), activation='relu', input_shape=(img_height, img_width, 3)),
    MaxPooling2D(pool_size=(2, 2)),
    
    Conv2D(64, (3, 3), activation='relu'),
    MaxPooling2D(pool_size=(2, 2)),
        
    Flatten(),
    Dense(64, activation='relu'),
    Dense(train_generator.num_classes, activation='softmax')
])

# Compile the model
model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])

# Train the model
# Out:
# Found 1561 images belonging to 15 classes.
# Found 383 images belonging to 15 classes.

# %%
epochs = 20
history = model.fit(
    train_generator,
    steps_per_epoch=train_generator.samples // batch_size,
    epochs=epochs,
    validation_data=validation_generator,
    validation_steps=validation_generator.samples // batch_size
)




# Evaluate the model on the validation data
val_loss, val_acc = model.evaluate(validation_generator)
print(f"Validation accuracy: {val_acc:.2f}, Validation loss: {val_loss:.2f}")
# Out:
# Epoch 1/20
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 53s 1s/step - accuracy: 0.1433 - loss: 3.0594 - val_accuracy: 0.2614 - val_loss: 2.4090
# Epoch 2/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 46s 981ms/step - accuracy: 0.3438 - loss: 2.1235
# 2024-10-15 21:01:27.029267: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 7ms/step - accuracy: 0.3438 - loss: 1.0839 - val_accuracy: 0.2581 - val_loss: 1.1428
# Epoch 3/20
# 2024-10-15 21:01:27.312591: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 52s 1s/step - accuracy: 0.4758 - loss: 1.7975 - val_accuracy: 0.3267 - val_loss: 2.3237
# Epoch 4/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 44s 937ms/step - accuracy: 0.5312 - loss: 1.4128
# 2024-10-15 21:02:20.494309: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.5312 - loss: 0.7211 - val_accuracy: 0.3548 - val_loss: 1.2415
# Epoch 5/20
# 2024-10-15 21:02:20.762342: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 46s 961ms/step - accuracy: 0.8468 - loss: 0.6822 - val_accuracy: 0.3324 - val_loss: 2.7071
# Epoch 6/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 39s 832ms/step - accuracy: 0.9688 - loss: 0.3047
# 2024-10-15 21:03:07.809840: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9688 - loss: 0.1555 - val_accuracy: 0.4839 - val_loss: 1.0711
# Epoch 7/20
# 2024-10-15 21:03:08.064680: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 44s 903ms/step - accuracy: 0.9569 - loss: 0.2708 - val_accuracy: 0.3040 - val_loss: 3.0957
# Epoch 8/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 39s 841ms/step - accuracy: 1.0000 - loss: 0.1230
# 2024-10-15 21:03:52.525072: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0628 - val_accuracy: 0.3548 - val_loss: 1.4589
# Epoch 9/20
# 2024-10-15 21:03:52.775905: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 45s 933ms/step - accuracy: 0.9899 - loss: 0.0999 - val_accuracy: 0.3409 - val_loss: 3.4809
# Epoch 10/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 37s 798ms/step - accuracy: 0.9688 - loss: 0.1814
# 2024-10-15 21:04:38.416127: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 0.9688 - loss: 0.0926 - val_accuracy: 0.3871 - val_loss: 1.7124
# Epoch 11/20
# 2024-10-15 21:04:38.660363: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 45s 927ms/step - accuracy: 0.9915 - loss: 0.0768 - val_accuracy: 0.3068 - val_loss: 3.6835
# Epoch 12/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 46s 995ms/step - accuracy: 1.0000 - loss: 0.1089
# 2024-10-15 21:05:24.263555: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0556 - val_accuracy: 0.4516 - val_loss: 1.2237
# Epoch 13/20
# 2024-10-15 21:05:24.511143: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 43s 902ms/step - accuracy: 0.9994 - loss: 0.0229 - val_accuracy: 0.3494 - val_loss: 4.0555
# Epoch 14/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 40s 857ms/step - accuracy: 1.0000 - loss: 0.0095
# 2024-10-15 21:06:08.885396: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0049 - val_accuracy: 0.3548 - val_loss: 1.8714
# Epoch 15/20
# 2024-10-15 21:06:09.126106: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 46s 962ms/step - accuracy: 1.0000 - loss: 0.0085 - val_accuracy: 0.3494 - val_loss: 4.4863
# Epoch 16/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 49s 1s/step - accuracy: 1.0000 - loss: 0.0069
# 2024-10-15 21:06:56.435813: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 5ms/step - accuracy: 1.0000 - loss: 0.0035 - val_accuracy: 0.3548 - val_loss: 2.2639
# Epoch 17/20
# 2024-10-15 21:06:56.654716: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 46s 962ms/step - accuracy: 1.0000 - loss: 0.0048 - val_accuracy: 0.3409 - val_loss: 4.5110
# Epoch 18/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 39s 851ms/step - accuracy: 1.0000 - loss: 0.0012
# 2024-10-15 21:07:43.800190: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 6.1469e-04 - val_accuracy: 0.1613 - val_loss: 3.6079
# Epoch 19/20
# 2024-10-15 21:07:44.065952: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 45s 936ms/step - accuracy: 1.0000 - loss: 0.0031 - val_accuracy: 0.3409 - val_loss: 4.8915
# Epoch 20/20
#  1/48 ━━━━━━━━━━━━━━━━━━━━ 44s 954ms/step - accuracy: 1.0000 - loss: 0.0045
# 2024-10-15 21:08:30.124839: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 48/48 ━━━━━━━━━━━━━━━━━━━━ 1s 6ms/step - accuracy: 1.0000 - loss: 0.0023 - val_accuracy: 0.3226 - val_loss: 1.7996
# 2024-10-15 21:08:30.385189: W tensorflow/core/framework/local_rendezvous.cc:404] Local rendezvous is aborting with status: OUT_OF_RANGE: End of sequence
# 	 [[{{node IteratorGetNext}}]]
# 12/12 ━━━━━━━━━━━━━━━━━━━━ 3s 250ms/step - accuracy: 0.3251 - loss: 4.8642
# Validation accuracy: 0.34, Validation loss: 4.78

# %%
import numpy as np
from tensorflow.keras.preprocessing import image
import matplotlib.pyplot as plt

# Set the path to the sample image
sample_image_path = 'sample6.jpg'  # Replace with the actual path to the sample image

# Preprocess the sample image
img_height, img_width = 224, 224
img = image.load_img(sample_image_path, target_size=(img_height, img_width))
img_array = image.img_to_array(img)
img_array = np.expand_dims(img_array, axis=0)  # Add batch dimension
img_array /= 255.0  # Rescale pixel values to [0, 1]

# Make a prediction using the existing model
prediction = model.predict(img_array)

# Get the predicted class index
predicted_class_index = np.argmax(prediction, axis=1)[0]

# Get the class labels from the train generator
class_labels = list(train_generator.class_indices.keys())

# Display the sample image and predicted class
plt.imshow(img)
plt.title(f"Predicted: {class_labels[predicted_class_index]}")
plt.axis('off')
plt.show()

# Print the predicted class label
print(f"Predicted class: {class_labels[predicted_class_index]}")
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 36ms/step
# Predicted class: Deer
